# %% [markdown]
# # charts

# %%
import numpy as np
import matplotlib.pyplot as plt
xD=np.array([5,4,6,9,6])
y=x **2
print(x)
print(y)
#visualization charts
# Out:
# [5 4 6 9 6]
# [25 16 36 81 36]

# %%
# Slicing

# %%
plt.plot(x,y, color='red',linestyle='--',linewidth='2')
plt.xlabel('x value');
plt.ylabel('y squared')
plt.show()

# %%
Categories=np.array(["Bajaj","Tuition fee","shopping", "makeup"])
Expenses=np.array([7,60,30,20])

# visualisation
plt.bar(Categories,Expenses, color='b')
plt.title('Monthly Expenses')
plt.xlabel('Catagories')
plt.ylabel('Expenses')
plt.show()

# %%
import matplotlib.pyplot as plt
expenses_pie=['rent','groceries','utilities','entertainment']
cost_pie=[100,200,100,150]

plt.pie(cost_pie,labels=expenses_pie, autopct='%1.1f%',startangle=90)
plt.title("monthly expenses distrobution. ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 expenses_pie=['rent','groceries','utilities','entertainment']
#       3 cost_pie=[100,200,100,150]
# ----> 5 plt.pie(cost_pie,labels=expenses_pie, autopct='%1.1f%',startingangle=90)
#       6 plt.title("monthly expenses distrobution. ")
#       7 plt.show()
#
# TypeError: pie() got an unexpected keyword argument 'startingangle'
